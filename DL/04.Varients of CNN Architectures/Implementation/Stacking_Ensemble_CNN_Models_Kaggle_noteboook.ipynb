# %% [markdown]
# # 🚀 How to Run this notebook in Kaggle
#
# Follow the steps below to execute this notebook using Kaggle Notebooks:
#
# ## Step 1: Open Kaggle
# Go to: https://www.kaggle.com/ and log in.
#
# ## Step 2: Create a New Notebook
# - Click **"Create" → "Notebook"**
# - A fresh Kaggle notebook environment will open.
#
# ## Step 3: Upload the Notebook
# - Click the **File** icon (left sidebar) → **Upload**
# - Upload this notebook
#
# ## Step 4: Attach the Dataset
# - Click **"Add Input"**
# - Search for the dataset: `https://www.kaggle.com/datasets/bharathsjm/alzheimers-data/data`
# - Press **Add**
# - The dataset will appear under the **Input** section.
#
# 💡 You can copy the dataset path from the **Input** section and paste it into the code below:
# ```python
# train_dir = "/kaggle/input/....
# test_dir = "kaggle/input/......"

# %%
# ===================== IMPORTS =====================
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense,
                                     Dropout, BatchNormalization, Input,
                                     Concatenate)


# ===================== DATA GENERATORS =====================
# Define the paths
train_dir = '/kaggle/input/datasets/bharathsjm/alzheimers-data/alzheimer dataset/train'
test_dir = '/kaggle/input/datasets/bharathsjm/alzheimers-data/alzheimer dataset/test'

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.4,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Simple rescaling for testing/validation
test_datagen = ImageDataGenerator(rescale=1./255)

# Load the images and labels, ensuring grayscale (1 channel)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    color_mode='grayscale',      # ✅ grayscale
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    color_mode='grayscale',      # ✅ grayscale
    class_mode='categorical'
)

# Infer number of classes from the generator
n_classes = 4
input_shape = (128, 128, 1)
# Out:
# Found 4647 images belonging to 4 classes.
# Found 1230 images belonging to 4 classes.

# %% [markdown]
# # **Build 3 CNN Models**

# %%
# ===================== BASE CNN MODELS =====================
# ------------- CNN1 -------------
CNN1 = Sequential()
CNN1.add(Conv2D(256, (3, 3), activation='relu', input_shape=input_shape))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(64, (3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(256, (3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(128, (3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Conv2D(256, (3, 3), activation='relu'))
CNN1.add(MaxPooling2D(pool_size=(2, 2)))

CNN1.add(Flatten())
CNN1.add(Dense(128, activation='relu'))
CNN1.add(Dropout(0.2))
CNN1.add(Dense(64, activation='relu'))
CNN1.add(Dense(n_classes, activation='softmax'))

CNN1.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

CNN1.summary()

CNN1.fit(train_generator,
          epochs=50,
          validation_data=test_generator)
# Out:
# I0000 00:00:1763813358.619851      48 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1763813358.620605      48 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 256)  │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 256)    │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,027,716 (3.92 MB)
#  Trainable params: 1,027,716 (3.92 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763813362.980131     139 service.cc:148] XLA service 0x79de18003600 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763813362.981205     139 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1763813362.981224     139 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1763813363.435917     139 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/146 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.1719 - loss: 1.3999
# I0000 00:00:1763813369.999658     139 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 232ms/step - accuracy: 0.5749 - loss: 1.0515 - val_accuracy: 0.3756 - val_loss: 1.3105
# Epoch 2/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.5915 - loss: 0.9488 - val_accuracy: 0.5699 - val_loss: 0.8705
# Epoch 3/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.5930 - loss: 0.8710 - val_accuracy: 0.6675 - val_loss: 0.8241
# Epoch 4/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.6247 - loss: 0.7960 - val_accuracy: 0.7943 - val_loss: 0.7172
# Epoch 5/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - accuracy: 0.6293 - loss: 0.7964 - val_accuracy: 0.7504 - val_loss: 0.6886
# Epoch 6/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.6589 - loss: 0.7558 - val_accuracy: 0.6520 - val_loss: 0.7713
# Epoch 7/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 87ms/step - accuracy: 0.6419 - loss: 0.7800 - val_accuracy: 0.6431 - val_loss: 0.8155
# Epoch 8/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.6511 - loss: 0.7507 - val_accuracy: 0.7789 - val_loss: 0.6279
# Epoch 9/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.6525 - loss: 0.7218 - val_accuracy: 0.7610 - val_loss: 0.6511
# Epoch 10/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.6822 - loss: 0.6923 - val_accuracy: 0.7122 - val_loss: 0.6258
# Epoch 11/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.6852 - loss: 0.6722 - val_accuracy: 0.7675 - val_loss: 0.6015
# Epoch 12/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6960 - loss: 0.6656 - val_accuracy: 0.7512 - val_loss: 0.5997
# Epoch 13/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7129 - loss: 0.6356 - val_accuracy: 0.7520 - val_loss: 0.5815
# Epoch 14/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.7042 - loss: 0.6328 - val_accuracy: 0.6780 - val_loss: 0.6742
# Epoch 15/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 89ms/step - accuracy: 0.7213 - loss: 0.6011 - val_accuracy: 0.7691 - val_loss: 0.5228
# Epoch 16/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.8409 - loss: 0.3783 - val_accuracy: 0.8415 - val_loss: 0.3712
# Epoch 27/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8251 - loss: 0.3982 - val_accuracy: 0.8130 - val_loss: 0.4103
# Epoch 28/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8473 - loss: 0.3640 - val_accuracy: 0.8642 - val_loss: 0.3347
# Epoch 29/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.8417 - loss: 0.3497 - val_accuracy: 0.9333 - val_loss: 0.1983
# Epoch 30/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8579 - loss: 0.3392 - val_accuracy: 0.9008 - val_loss: 0.2682
# Epoch 31/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8744 - loss: 0.3139 - val_accuracy: 0.9187 - val_loss: 0.2442
# Epoch 32/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8786 - loss: 0.3035 - val_accuracy: 0.8772 - val_loss: 0.3047
# Epoch 33/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8753 - loss: 0.3070 - val_accuracy: 0.9382 - val_loss: 0.1759
# Epoch 34/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8862 - loss: 0.2847 - val_accuracy: 0.9724 - val_loss: 0.1092
# Epoch 35/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.9069 - loss: 0.2325 - val_accuracy: 0.9431 - val_loss: 0.1739
# Epoch 36/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8984 - loss: 0.2608 - val_accuracy: 0.9244 - val_loss: 0.1961
# Epoch 37/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.9008 - loss: 0.2679 - val_accuracy: 0.8805 - val_loss: 0.3139
# Epoch 38/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.8931 - loss: 0.2745 - val_accuracy: 0.9163 - val_loss: 0.2015
# Epoch 39/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.9190 - loss: 0.2080 - val_accuracy: 0.9748 - val_loss: 0.0828
# Epoch 40/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8934 - loss: 0.2501 - val_accuracy: 0.9618 - val_loss: 0.1254
# Epoch 41/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.9142 - loss: 0.2244 - val_accuracy: 0.9504 - val_loss: 0.1260
# Epoch 42/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.9145 - loss: 0.2189 - val_accuracy: 0.9512 - val_loss: 0.1312
# Epoch 43/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.9308 - loss: 0.1789 - val_accuracy: 0.9748 - val_loss: 0.0880
# Epoch 44/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.9283 - loss: 0.1890 - val_accuracy: 0.9496 - val_loss: 0.1318
# Epoch 45/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - accuracy: 0.9309 - loss: 0.1726 - val_accuracy: 0.9504 - val_loss: 0.1409
# Epoch 46/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.9314 - loss: 0.1804 - val_accuracy: 0.9480 - val_loss: 0.1055
# Epoch 47/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.9351 - loss: 0.1703 - val_accuracy: 0.9634 - val_loss: 0.0995
# Epoch 48/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - accuracy: 0.9360 - loss: 0.1682 - val_accuracy: 0.9390 - val_loss: 0.1470
# Epoch 49/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.9413 - loss: 0.1629 - val_accuracy: 0.9870 - val_loss: 0.0515
# Epoch 50/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.9390 - loss: 0.1708 - val_accuracy: 0.9724 - val_loss: 0.0694

# %%
# ===================== EVALUATE =====================
loss, acc = CNN1.evaluate(test_generator)
print(f"\nCNN1 Test Accuracy: {acc:.4f}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9721 - loss: 0.0681
#
# CNN1 Test Accuracy: 0.9724

# %%
# ------------- CNN2 -------------
CNN2 = Sequential([
    Conv2D(64, (3,3), activation='relu', padding='same', input_shape=input_shape),
    BatchNormalization(),
    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(128, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Conv2D(256, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.4),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(n_classes, activation='softmax')
])

CNN2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

CNN2.summary()

CNN2.fit(train_generator,
          epochs=50,
          validation_data=test_generator)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 128, 128, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │    16,777,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,365,828 (66.25 MB)
#  Trainable params: 17,365,444 (66.24 MB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 43s 188ms/step - accuracy: 0.5451 - loss: 2.1600 - val_accuracy: 0.1748 - val_loss: 1.2826
# Epoch 2/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6163 - loss: 0.8486 - val_accuracy: 0.7382 - val_loss: 0.9885
# Epoch 3/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.6181 - loss: 0.8309 - val_accuracy: 0.6715 - val_loss: 0.7950
# Epoch 4/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6338 - loss: 0.8100 - val_accuracy: 0.6480 - val_loss: 0.8103
# Epoch 5/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.6363 - loss: 0.7762 - val_accuracy: 0.7358 - val_loss: 0.7765
# Epoch 6/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6599 - loss: 0.7467 - val_accuracy: 0.7374 - val_loss: 0.7603
# Epoch 7/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.6471 - loss: 0.7805 - val_accuracy: 0.7610 - val_loss: 0.7090
# Epoch 8/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6742 - loss: 0.7431 - val_accuracy: 0.7049 - val_loss: 0.8538
# Epoch 9/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6829 - loss: 0.7093 - val_accuracy: 0.7390 - val_loss: 0.7631
# Epoch 10/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.6535 - loss: 0.7420 - val_accuracy: 0.5463 - val_loss: 1.0290
# Epoch 11/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 97ms/step - accuracy: 0.6778 - loss: 0.7096 - val_accuracy: 0.5415 - val_loss: 0.9737
# Epoch 12/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6672 - loss: 0.7171 - val_accuracy: 0.7293 - val_loss: 0.6341
# Epoch 13/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6753 - loss: 0.6938 - val_accuracy: 0.6878 - val_loss: 0.7022
# Epoch 14/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7046 - loss: 0.6702 - val_accuracy: 0.6171 - val_loss: 0.7866
# Epoch 15/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7053 - loss: 0.6721 - val_accuracy: 0.6780 - val_loss: 0.6971
# Epoch 16/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 98ms/step - accuracy: 0.6936 - loss: 0.6562 - val_accuracy: 0.6220 - val_loss: 0.9137
# Epoch 17/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.6937 - loss: 0.6581 - val_accuracy: 0.7772 - val_loss: 0.5492
# Epoch 18/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7186 - loss: 0.6185 - val_accuracy: 0.7707 - val_loss: 0.5442
# Epoch 19/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step - accuracy: 0.7268 - loss: 0.6123 - val_accuracy: 0.8081 - val_loss: 0.5102
# Epoch 20/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7240 - loss: 0.5963 - val_accuracy: 0.7358 - val_loss: 0.5904
# Epoch 21/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7375 - loss: 0.5848 - val_accuracy: 0.7699 - val_loss: 0.5646
# Epoch 22/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.7377 - loss: 0.5725 - val_accuracy: 0.8033 - val_loss: 0.5371
# Epoch 23/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.7350 - loss: 0.5774 - val_accuracy: 0.7642 - val_loss: 0.5082
# Epoch 24/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.7545 - loss: 0.5567 - val_accuracy: 0.8398 - val_loss: 0.4390
# Epoch 25/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7442 - loss: 0.5515 - val_accuracy: 0.8659 - val_loss: 0.3926
# Epoch 26/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7456 - loss: 0.5580 - val_accuracy: 0.8813 - val_loss: 0.3782
# Epoch 27/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.7730 - loss: 0.4958 - val_accuracy: 0.7423 - val_loss: 0.5905
# Epoch 32/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7746 - loss: 0.5116 - val_accuracy: 0.8211 - val_loss: 0.4148
# Epoch 33/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.7859 - loss: 0.4958 - val_accuracy: 0.8407 - val_loss: 0.4857
# Epoch 34/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.7870 - loss: 0.4980 - val_accuracy: 0.8220 - val_loss: 0.4026
# Epoch 35/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.7728 - loss: 0.4908 - val_accuracy: 0.8146 - val_loss: 0.3903
# Epoch 36/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8005 - loss: 0.4649 - val_accuracy: 0.8488 - val_loss: 0.3968
# Epoch 37/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8030 - loss: 0.4562 - val_accuracy: 0.8813 - val_loss: 0.3415
# Epoch 38/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8197 - loss: 0.4246 - val_accuracy: 0.8902 - val_loss: 0.3383
# Epoch 39/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8197 - loss: 0.4493 - val_accuracy: 0.8423 - val_loss: 0.4348
# Epoch 40/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8131 - loss: 0.4337 - val_accuracy: 0.8203 - val_loss: 0.4092
# Epoch 41/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8134 - loss: 0.4278 - val_accuracy: 0.8333 - val_loss: 0.4292
# Epoch 42/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8171 - loss: 0.4105 - val_accuracy: 0.9122 - val_loss: 0.2478
# Epoch 43/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8279 - loss: 0.4047 - val_accuracy: 0.8041 - val_loss: 0.4909
# Epoch 44/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8252 - loss: 0.4071 - val_accuracy: 0.8935 - val_loss: 0.2914
# Epoch 45/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8357 - loss: 0.3876 - val_accuracy: 0.8805 - val_loss: 0.2949
# Epoch 46/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.8292 - loss: 0.4129 - val_accuracy: 0.8813 - val_loss: 0.3041
# Epoch 47/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8316 - loss: 0.4028 - val_accuracy: 0.9008 - val_loss: 0.2487
# Epoch 48/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.8347 - loss: 0.3892 - val_accuracy: 0.9179 - val_loss: 0.2580
# Epoch 49/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8489 - loss: 0.3699 - val_accuracy: 0.9171 - val_loss: 0.2220
# Epoch 50/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step - accuracy: 0.8420 - loss: 0.3578 - val_accuracy: 0.8699 - val_loss: 0.3275

# %%
# ===================== EVALUATE =====================
loss, acc = CNN2.evaluate(test_generator)
print(f"\nCNN2 Test Accuracy: {acc:.4f}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8769 - loss: 0.3218
#
# CNN2 Test Accuracy: 0.8699

# %%
# ------------- CNN3 -------------
CNN3 = Sequential([
    Conv2D(32, (5,5), activation='relu', padding='same', input_shape=input_shape),
    MaxPooling2D((2,2)),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(n_classes, activation='softmax')
])

CNN3.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

CNN3.summary()


CNN3.fit(train_generator,
          epochs=50,
          validation_data=test_generator)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 128, 128, 32)   │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,290,500 (4.92 MB)
#  Trainable params: 1,290,244 (4.92 MB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.5364 - loss: 1.2273 - val_accuracy: 0.3756 - val_loss: 1.3574
# Epoch 2/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6034 - loss: 0.8690 - val_accuracy: 0.4585 - val_loss: 1.3022
# Epoch 3/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.6161 - loss: 0.8160 - val_accuracy: 0.6642 - val_loss: 1.1652
# Epoch 4/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.6325 - loss: 0.7842 - val_accuracy: 0.5837 - val_loss: 0.8926
# Epoch 5/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.6495 - loss: 0.7570 - val_accuracy: 0.5569 - val_loss: 0.7664
# Epoch 6/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.6628 - loss: 0.7331 - val_accuracy: 0.7593 - val_loss: 0.7478
# Epoch 7/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.6729 - loss: 0.7487 - val_accuracy: 0.6569 - val_loss: 0.7607
# Epoch 8/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.6743 - loss: 0.7146 - val_accuracy: 0.7154 - val_loss: 0.7079
# Epoch 9/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.6885 - loss: 0.6778 - val_accuracy: 0.7870 - val_loss: 0.6703
# Epoch 10/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.6828 - loss: 0.6732 - val_accuracy: 0.7886 - val_loss: 0.5627
# Epoch 11/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7065 - loss: 0.6536 - val_accuracy: 0.6106 - val_loss: 1.1543
# Epoch 12/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.6944 - loss: 0.6473 - val_accuracy: 0.6333 - val_loss: 0.7402
# Epoch 13/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7179 - loss: 0.6498 - val_accuracy: 0.7179 - val_loss: 0.5723
# Epoch 14/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.7153 - loss: 0.6129 - val_accuracy: 0.7463 - val_loss: 0.5829
# Epoch 15/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7248 - loss: 0.5974 - val_accuracy: 0.6780 - val_loss: 0.6005
# Epoch 16/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7207 - loss: 0.5849 - val_accuracy: 0.8325 - val_loss: 0.4510
# Epoch 17/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7330 - loss: 0.5572 - val_accuracy: 0.7309 - val_loss: 0.5309
# Epoch 18/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.7346 - loss: 0.5678 - val_accuracy: 0.7382 - val_loss: 0.5273
# Epoch 19/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.7397 - loss: 0.5595 - val_accuracy: 0.8325 - val_loss: 0.4140
# Epoch 20/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.7678 - loss: 0.5204 - val_accuracy: 0.8171 - val_loss: 0.4562
# Epoch 21/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.7609 - loss: 0.5168 - val_accuracy: 0.7967 - val_loss: 0.4814
# Epoch 22/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7789 - loss: 0.5015 - val_accuracy: 0.8496 - val_loss: 0.3686
# Epoch 23/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.7783 - loss: 0.4827 - val_accuracy: 0.8715 - val_loss: 0.3456
# Epoch 24/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.7787 - loss: 0.4944 - val_accuracy: 0.7756 - val_loss: 0.4436
# Epoch 25/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.7965 - loss: 0.4500 - val_accuracy: 0.8846 - val_loss: 0.2928
# Epoch 26/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.7929 - loss: 0.4648 - val_accuracy: 0.8537 - val_loss: 0.3833
# Epoch 27/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8088 - loss: 0.4258 - val_accuracy: 0.8821 - val_loss: 0.2954
# Epoch 28/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.8039 - loss: 0.4634 - val_accuracy: 0.8325 - val_loss: 0.4058
# Epoch 29/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.8160 - loss: 0.4202 - val_accuracy: 0.9276 - val_loss: 0.2142
# Epoch 30/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8202 - loss: 0.4177 - val_accuracy: 0.7967 - val_loss: 0.4167
# Epoch 31/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8063 - loss: 0.4409 - val_accuracy: 0.8585 - val_loss: 0.3182
# Epoch 32/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.8365 - loss: 0.3899 - val_accuracy: 0.8642 - val_loss: 0.3291
# Epoch 33/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8374 - loss: 0.4014 - val_accuracy: 0.8935 - val_loss: 0.2497
# Epoch 34/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8376 - loss: 0.3822 - val_accuracy: 0.8659 - val_loss: 0.2900
# Epoch 35/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.8524 - loss: 0.3556 - val_accuracy: 0.8976 - val_loss: 0.2512
# Epoch 36/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.8582 - loss: 0.3451 - val_accuracy: 0.8943 - val_loss: 0.2458
# Epoch 37/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.8562 - loss: 0.3368 - val_accuracy: 0.9106 - val_loss: 0.2310
# Epoch 38/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8525 - loss: 0.3500 - val_accuracy: 0.9016 - val_loss: 0.2388
# Epoch 39/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 93ms/step - accuracy: 0.8526 - loss: 0.3514 - val_accuracy: 0.9496 - val_loss: 0.1406
# Epoch 40/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 14s 95ms/step - accuracy: 0.8571 - loss: 0.3385 - val_accuracy: 0.9407 - val_loss: 0.1543
# Epoch 41/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 88ms/step - accuracy: 0.8580 - loss: 0.3373 - val_accuracy: 0.9081 - val_loss: 0.2226
# Epoch 42/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8585 - loss: 0.3292 - val_accuracy: 0.9179 - val_loss: 0.1875
# Epoch 43/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - accuracy: 0.8696 - loss: 0.3002 - val_accuracy: 0.9171 - val_loss: 0.2046
# Epoch 44/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.8821 - loss: 0.2823 - val_accuracy: 0.9114 - val_loss: 0.2068
# Epoch 45/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8778 - loss: 0.3086 - val_accuracy: 0.9008 - val_loss: 0.2141
# Epoch 46/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - accuracy: 0.8951 - loss: 0.2754 - val_accuracy: 0.9764 - val_loss: 0.0938
# Epoch 47/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 80ms/step - accuracy: 0.8900 - loss: 0.2747 - val_accuracy: 0.9553 - val_loss: 0.1183
# Epoch 48/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.8936 - loss: 0.2637 - val_accuracy: 0.9325 - val_loss: 0.1764
# Epoch 49/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 85ms/step - accuracy: 0.9029 - loss: 0.2549 - val_accuracy: 0.9317 - val_loss: 0.1666
# Epoch 50/50
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 81ms/step - accuracy: 0.8898 - loss: 0.2803 - val_accuracy: 0.8642 - val_loss: 0.3094

# %%
# ===================== EVALUATE =====================
loss, acc = CNN3.evaluate(test_generator)
print(f"\nCNN3 Test Accuracy: {acc:.4f}")
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8766 - loss: 0.2843
#
# CNN3 Test Accuracy: 0.8642

# %%
#To freeze the first-level CNN models so that during the second-level training:
#ONLY the MLP_meta (second-level model) learns. The CNNs do NOT get updated again.
#This is the correct stacking behavior.

for base_model in [CNN1, CNN2, CNN3]:
    base_model.trainable = False

# Shared input
stack_input = Input(shape=input_shape)

# Get softmax outputs from each base model
pred1 = CNN1(stack_input)
pred2 = CNN2(stack_input)
pred3 = CNN3(stack_input)

# Concatenate predictions -> meta-features
merged = Concatenate()([pred1, pred2, pred3])   # shape: (None, 3 * n_classes)

meta_input_dim = 3 * n_classes  # e.g., 3 * 4 = 12

MLP_meta = Sequential(name="MLP_meta")
MLP_meta.add(Dense(32, activation='relu', input_shape=(meta_input_dim,)))
MLP_meta.add(Dense(32, activation='relu'))
MLP_meta.add(Dropout(0.5))
MLP_meta.add(Dense(n_classes, activation='softmax'))

# Pass merged predictions to MLP_meta
stack_output = MLP_meta(merged)

# Final stacking model
Stacking_Model = Model(inputs=stack_input, outputs=stack_output)

Stacking_Model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

Stacking_Model.summary()
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 4)         │  1,027,716 │ input_layer_3[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 4)         │ 17,365,828 │ input_layer_3[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 4)         │  1,290,500 │ input_layer_3[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12)        │          0 │ sequential[0][0], │
# │ (Concatenate)       │                   │            │ sequential_1[0][… │
# │                     │                   │            │ sequential_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ MLP_meta            │ (None, 4)         │      1,604 │ concatenate[0][0] │
# │ (Sequential)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 19,685,648 (75.09 MB)
#  Trainable params: 1,604 (6.27 KB)
#  Non-trainable params: 19,684,044 (75.09 MB)

# %%
# ===================== TRAIN STACKING MODEL =====================
# Now train the stacking ensemble using the generators
epochs_stack = 3

history_stack = Stacking_Model.fit(
    train_generator,
    epochs=epochs_stack,
    validation_data=test_generator
)

# ===================== EVALUATE =====================
loss, acc = Stacking_Model.evaluate(test_generator)
print(f"\nStacking Model Test Accuracy: {acc:.4f}")
# Out:
# Epoch 1/3
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.6450 - loss: 0.9065 - val_accuracy: 0.9577 - val_loss: 0.1770
# Epoch 2/3
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 13s 85ms/step - accuracy: 0.9360 - loss: 0.2280 - val_accuracy: 0.9789 - val_loss: 0.0978
# Epoch 3/3
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 0.9471 - loss: 0.1715 - val_accuracy: 0.9837 - val_loss: 0.0737
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9821 - loss: 0.0751
#
# Stacking Model Test Accuracy: 0.9837
